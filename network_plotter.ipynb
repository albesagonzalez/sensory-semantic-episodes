# %% [markdown]
# # network_plotter
#
# Load a recorded network checkpoint and render one structural snapshot of simultaneous activity across CTX, MTL, MTL-sensory, and MTL-semantic for a selected `[day, wake_sleep, timestep]`.

# %%
import torch

import matplotlib.pyplot as plt
from network_plotter import (
    blue_yellow,
    get_recording_schedule,
    plot_network_snapshot,
    summarize_recording_schedule,
)

# %%
network = torch.load("checkpoints/network_4_recordings.pt", weights_only=False)
schedule_summary = summarize_recording_schedule(network)
schedule_summary
# Out:
# {'num_awake_days': 1,
#  'num_sleep_a_days': 1,
#  'num_sleep_b_days': 1,
#  'awake_timesteps_per_day': [80],
#  'sleep_a_timesteps_per_day': [10],
#  'sleep_b_timesteps_per_day': [10]}

# %%
day = 0  # relative recorded day; network_4_recordings.pt stores one awake day
wake_sleep = 0  # 0 = awake, 1 = sleep-A
timestep = 0

# %%
import importlib
import network_plotter

importlib.reload(network_plotter)

from network_plotter import (
    blue_yellow,
    get_recording_schedule,
    plot_network_snapshot,
    summarize_recording_schedule,
)


fig, axes = plot_network_snapshot(
    network,
    day=day,
    wake_sleep=wake_sleep,
    timestep=timestep,
    cmap=blue_yellow,
)


plt.savefig("Figures_SVG/1b.svg", dpi=300, transparent=True)
